# %% [markdown]
# # How Men and Women Commute in NYC

# %%
import pandas as pd

# %%
# load data in a dataframe ('df')
df = pd.read_csv('ACS_14_5YR_S0801_with_ann.csv')

# %%
# preview the df
df.head()
# Out:
#                  GEO.id      GEO.id2                        GEO.display-label  \
# 0                    Id          Id2                                Geography
# 1  1400000US36005000100  36005000100   Census Tract 1, Bronx County, New York
# 2  1400000US36005000200  36005000200   Census Tract 2, Bronx County, New York
# 3  1400000US36005000400  36005000400   Census Tract 4, Bronx County, New York
# 4  1400000US36005001600  36005001600  Census Tract 16, Bronx County, New York
#
#                                 HC01_EST_VC01  \
# 0  Total; Estimate; Workers 16 years and over
# 1                                           0
# 2                                        2102
# 3                                        2588
# 4                                        1946
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Workers 16 years and over
# 1                                                 16
# ...

# %%
# remove margin of error columns
margins_of_error = [column for column in df.columns if 'MOE' in column]
df.drop(margins_of_error,inplace=True,axis=1)

# %%
# preview df to make sure the MOE columns were successfully dropped
df.head()
# Out:
#                  GEO.id      GEO.id2                        GEO.display-label  \
# 0                    Id          Id2                                Geography
# 1  1400000US36005000100  36005000100   Census Tract 1, Bronx County, New York
# 2  1400000US36005000200  36005000200   Census Tract 2, Bronx County, New York
# 3  1400000US36005000400  36005000400   Census Tract 4, Bronx County, New York
# 4  1400000US36005001600  36005001600  Census Tract 16, Bronx County, New York
#
#                                 HC01_EST_VC01  \
# 0  Total; Estimate; Workers 16 years and over
# 1                                           0
# 2                                        2102
# 3                                        2588
# 4                                        1946
#
#                                HC02_EST_VC01  \
# 0  Male; Estimate; Workers 16 years and over
# 1                                          0
# 2                                       1060
# ...

# %%
# save the first row because we will be dropping it
headers = df.columns

# %%
# set the column headers equal to first row
df.columns = df.iloc[0]

# %%
# drop the second row
df.drop(0,inplace=True,axis=0)

# %%
# view male columns
[column for column in df.columns if 'MEANS OF TRANSPORTATION' in column and 'Male' in column]
# Out:
# ['Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Drove alone',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled - In 2-person carpool',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled - In 3-person carpool',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled - In 4-or-more person carpool',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Workers per car, truck, or van',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Public transportation (excluding taxicab)',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Walked',
#  'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Bicycle',
# ...

# %%
# view female columns
[column for column in df.columns if 'MEANS OF TRANSPORTATION' in column and 'Female' in column]
# Out:
# ['Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Drove alone',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled - In 2-person carpool',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled - In 3-person carpool',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled - In 4-or-more person carpool',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Workers per car, truck, or van',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Public transportation (excluding taxicab)',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Walked',
#  'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Bicycle',
# ...

# %%
# create male transportation df
male_columns = ['Id', 'Id2', 'Geography'] + [column for column in df.columns if \
                                             'MEANS OF TRANSPORTATION' in column and \
                                             'Male' in column and 'person carpool' not in column and \
                                             'Workers per car' not in column]
men = df[male_columns]

# create female transportation df
female_columns = ['Id', 'Id2', 'Geography'] + [column for column in df.columns if \
                                             'MEANS OF TRANSPORTATION' in column and \
                                             'Female' in column and 'person carpool' not in column and \
                                             'Workers per car' not in column]

women = df[female_columns]

# %%
men
# Out:
# 0                       Id          Id2  \
# 1     1400000US36005000100  36005000100
# 2     1400000US36005000200  36005000200
# 3     1400000US36005000400  36005000400
# 4     1400000US36005001600  36005001600
# 5     1400000US36005001900  36005001900
# 6     1400000US36005002000  36005002000
# 7     1400000US36005002300  36005002300
# 8     1400000US36005002400  36005002400
# 9     1400000US36005002500  36005002500
# 10    1400000US36005002701  36005002701
# 11    1400000US36005002702  36005002702
# 12    1400000US36005002800  36005002800
# 13    1400000US36005003100  36005003100
# 14    1400000US36005003300  36005003300
# 15    1400000US36005003500  36005003500
# 16    1400000US36005003700  36005003700
# 17    1400000US36005003800  36005003800
# 18    1400000US36005003900  36005003900
# 19    1400000US36005004001  36005004001
# 20    1400000US36005004100  36005004100
# 21    1400000US36005004200  36005004200
# 22    1400000US36005004300  36005004300
# ...

# %%
# rename male columns
men = men.rename(columns={
        'Id': 'GeoID',
        'Id2': 'GeoID2',
        'Geography': 'GeoDisplay',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van': 'Drive',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Drove alone': 'Drive_alone',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled': 'Carpool',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Public transportation (excluding taxicab)': 'Transit',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Walked': 'Walk',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Bicycle': 'Bike',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Taxicab, motorcycle, or other means': 'Other',
        'Male; Estimate; MEANS OF TRANSPORTATION TO WORK - Worked at home': 'Work_from_home'
    })


# rename women columns
women = women.rename(columns={
        'Id': 'GeoID',
        'Id2': 'GeoID2',
        'Geography': 'GeoDisplay',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van': 'Drive',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Drove alone': 'Drive_alone',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Car, truck, or van - Carpooled': 'Carpool',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Public transportation (excluding taxicab)': 'Transit',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Walked': 'Walk',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Bicycle': 'Bike',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Taxicab, motorcycle, or other means': 'Other',
        'Female; Estimate; MEANS OF TRANSPORTATION TO WORK - Worked at home': 'Work_from_home'
    })

# %%
# preview men
men.head()
# Out:
# 0                 GeoID       GeoID2                               GeoDisplay  \
# 1  1400000US36005000100  36005000100   Census Tract 1, Bronx County, New York
# 2  1400000US36005000200  36005000200   Census Tract 2, Bronx County, New York
# 3  1400000US36005000400  36005000400   Census Tract 4, Bronx County, New York
# 4  1400000US36005001600  36005001600  Census Tract 16, Bronx County, New York
# 5  1400000US36005001900  36005001900  Census Tract 19, Bronx County, New York
#
# 0 Drive Drive_alone Carpool Transit Walk Bike Other Work_from_home
# 1     -           -       -       -    -    -     -              -
# 2  69.9        59.7    10.2    24.8  4.2  0.0   0.0            1.1
# 3  54.8        49.9     4.9    37.6  2.5  0.0   1.1            4.0
# 4  46.6        35.6    11.0    48.6  4.8  0.0   0.0            0.0
# 5  13.6         8.7     4.9    80.1  1.7  0.9   0.0            3.6

# %%
# preview women
women.head()
# Out:
# 0                 GeoID       GeoID2                               GeoDisplay  \
# 1  1400000US36005000100  36005000100   Census Tract 1, Bronx County, New York
# 2  1400000US36005000200  36005000200   Census Tract 2, Bronx County, New York
# 3  1400000US36005000400  36005000400   Census Tract 4, Bronx County, New York
# 4  1400000US36005001600  36005001600  Census Tract 16, Bronx County, New York
# 5  1400000US36005001900  36005001900  Census Tract 19, Bronx County, New York
#
# 0 Drive Drive_alone Carpool Transit Walk Bike Other Work_from_home
# 1     -           -       -       -    -    -     -              -
# 2  56.9        36.7    20.2    43.1  0.0  0.0   0.0            0.0
# 3  41.7        32.4     9.3    56.3  2.0  0.0   0.0            0.0
# 4  39.1        22.6    16.4    46.2  9.9  0.0   2.8            2.0
# 5  31.8        21.0    10.8    51.3  4.1  0.0   3.2            9.6

# %%
men
# Out:
# 0                    GeoID       GeoID2  \
# 1     1400000US36005000100  36005000100
# 2     1400000US36005000200  36005000200
# 3     1400000US36005000400  36005000400
# 4     1400000US36005001600  36005001600
# 5     1400000US36005001900  36005001900
# 6     1400000US36005002000  36005002000
# 7     1400000US36005002300  36005002300
# 8     1400000US36005002400  36005002400
# 9     1400000US36005002500  36005002500
# 10    1400000US36005002701  36005002701
# 11    1400000US36005002702  36005002702
# 12    1400000US36005002800  36005002800
# 13    1400000US36005003100  36005003100
# 14    1400000US36005003300  36005003300
# 15    1400000US36005003500  36005003500
# 16    1400000US36005003700  36005003700
# 17    1400000US36005003800  36005003800
# 18    1400000US36005003900  36005003900
# 19    1400000US36005004001  36005004001
# 20    1400000US36005004100  36005004100
# 21    1400000US36005004200  36005004200
# 22    1400000US36005004300  36005004300
# ...

# %%
# remove rows with dashes
men = men[men.Drive != '-']
women = women[women.Drive != '-']

# %%
men.head()
# Out:
# 0                 GeoID       GeoID2                               GeoDisplay  \
# 2  1400000US36005000200  36005000200   Census Tract 2, Bronx County, New York
# 3  1400000US36005000400  36005000400   Census Tract 4, Bronx County, New York
# 4  1400000US36005001600  36005001600  Census Tract 16, Bronx County, New York
# 5  1400000US36005001900  36005001900  Census Tract 19, Bronx County, New York
# 6  1400000US36005002000  36005002000  Census Tract 20, Bronx County, New York
#
# 0 Drive Drive_alone Carpool Transit Walk Bike Other Work_from_home
# 2  69.9        59.7    10.2    24.8  4.2  0.0   0.0            1.1
# 3  54.8        49.9     4.9    37.6  2.5  0.0   1.1            4.0
# 4  46.6        35.6    11.0    48.6  4.8  0.0   0.0            0.0
# 5  13.6         8.7     4.9    80.1  1.7  0.9   0.0            3.6
# 6  33.4        26.2     7.2    66.6  0.0  0.0   0.0            0.0

# %%
# Convert men data types to floats
men.Drive = men.Drive.astype(float)
men.Drive_alone = men.Drive_alone.astype(float)
men.Carpool = men.Carpool.astype(float)
men.Transit = men.Transit.astype(float)
men.Walk = men.Walk.astype(float)
men.Bike = men.Bike.astype(float)
men.Other = men.Other.astype(float)
men.Work_from_home = men.Work_from_home.astype(float)

# %%
men.dtypes
# Out:
# 0
# GeoID              object
# GeoID2             object
# GeoDisplay         object
# Drive             float64
# Drive_alone       float64
# Carpool           float64
# Transit           float64
# Walk              float64
# Bike              float64
# Other             float64
# Work_from_home    float64
# dtype: object

# %%
# Convert women data types to floats
women.Drive = women.Drive.astype(float)
women.Drive_alone = women.Drive_alone.astype(float)
women.Carpool = women.Carpool.astype(float)
women.Transit = women.Transit.astype(float)
women.Walk = women.Walk.astype(float)
women.Bike = women.Bike.astype(float)
women.Other = women.Other.astype(float)
women.Work_from_home = women.Work_from_home.astype(float)

# %%
women.dtypes
# Out:
# 0
# GeoID              object
# GeoID2             object
# GeoDisplay         object
# Drive             float64
# Drive_alone       float64
# Carpool           float64
# Transit           float64
# Walk              float64
# Bike              float64
# Other             float64
# Work_from_home    float64
# dtype: object

# %%
# save dfs to csv
men.to_csv('men.csv', index=False)
women.to_csv('women.csv', index=False)
